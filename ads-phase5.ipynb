# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from datetime import datetime,timedelta
ds = pd.read_csv("NetflixOriginals.csv",encoding = "cp1252")
ds_date = ds.copy()
ds.head()
# Out:
#              Title                  Genre           Premiere  Runtime  \
# 0  Enter the Anime            Documentary     August 5, 2019       58
# 1      Dark Forces               Thriller    August 21, 2020       81
# 2          The App  Science fiction/Drama  December 26, 2019       79
# 3   The Open House        Horror thriller   January 19, 2018       94
# 4      Kaali Khuhi                Mystery   October 30, 2020       90
#
#    IMDB Score          Language
# 0         2.5  English/Japanese
# 1         2.6           Spanish
# 2         2.6           Italian
# 3         3.2           English
# 4         3.4             Hindi

# %%
ds.describe().T
# Out:
#             count       mean        std  min   25%   50%    75%    max
# Runtime     583.0  93.555746  27.780742  4.0  86.0  97.0  108.0  209.0
# IMDB Score  583.0   6.273070   0.979574  2.5   5.7   6.4    7.0    9.0

# %%
ds.info(verbose=True,show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Title       583 non-null    object
#  1   Genre       583 non-null    object
#  2   Premiere    583 non-null    object
#  3   Runtime     583 non-null    int64
#  4   IMDB Score  583 non-null    float64
#  5   Language    583 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 27.5+ KB

# %%
ds.isna().sum()
# Out:
# Title         0
# Genre         0
# Premiere      0
# Runtime       0
# IMDB Score    0
# Language      0
# dtype: int64

# %%
ds['Title'].value_counts()
# Out:
# Title
# Enter the Anime                                       1
# Arlo the Alligator Boy                                1
# The Old Guard                                         1
# Tony Robbins: I Am Not Your Guru                      1
# Upstarts                                              1
#                                                      ..
# Earthquake Bird                                       1
# Frankenstein's Monster's Monster, Frankenstein        1
# Horse Girl                                            1
# Notes from Dunblane: Lesson from a School Shooting    1
# David Attenborough: A Life on Our Planet              1
# Name: count, Length: 583, dtype: int64

# %%
ds['Genre'].value_counts()
# Out:
# Genre
# Documentary                             159
# Drama                                    77
# Comedy                                   49
# Romantic comedy                          39
# Thriller                                 33
#                                        ...
# Comedy horror                             1
# Romantic teen drama                       1
# Christian musical                         1
# Horror comedy                             1
# Animation/Christmas/Comedy/Adventure      1
# Name: count, Length: 115, dtype: int64

# %%
ds['Premiere'].value_counts()
# Out:
# Premiere
# October 2, 2020       5
# November 1, 2019      5
# October 18, 2019      5
# November 2, 2018      4
# June 19, 2020         4
#                      ..
# September 20, 2019    1
# March 10, 2017        1
# March 17, 2017        1
# May 29, 2015          1
# October 4, 2020       1
# Name: count, Length: 390, dtype: int64

# %%
ds_date["Premiere"] = ds_date["Premiere"].apply(lambda x: "".join(x for x in x.replace(".",",")))
ds_date["PremiereDate"] = ds_date["Premiere"].apply(lambda x: datetime.strptime(x, "%B %d, %Y").date())
ds_date["Year"] = ds_date["Premiere"].apply(lambda x: "".join(x for x in x.replace(",","").split()[-1]))

#Convert object to date
ds_date["PremiereDate"] = pd.to_datetime(ds_date["PremiereDate"]) 
ds_date
# Out:
#                                            Title                  Genre  \
# 0                                Enter the Anime            Documentary
# 1                                    Dark Forces               Thriller
# 2                                        The App  Science fiction/Drama
# 3                                 The Open House        Horror thriller
# 4                                    Kaali Khuhi                Mystery
# ..                                           ...                    ...
# 578        Taylor Swift: Reputation Stadium Tour           Concert Film
# 579  Winter on Fire: Ukraine's Fight for Freedom            Documentary
# 580                      Springsteen on Broadway           One-man show
# 581    Emicida: AmarElo - It's All For Yesterday            Documentary
# 582     David Attenborough: A Life on Our Planet            Documentary
#
#               Premiere  Runtime  IMDB Score                  Language  \
# 0       August 5, 2019       58         2.5          English/Japanese
# 1      August 21, 2020       81         2.6                   Spanish
# 2    December 26, 2019       79         2.6                   Italian
# 3     January 19, 2018       94         3.2                   English
# 4     October 30, 2020       90         3.4                     Hindi
# ..                 ...      ...         ...                       ...
# 578  December 31, 2018      125         8.4                   English
# 579    October 9, 2015       91         8.4  English/Ukranian/Russian
# 580  December 16, 2018      153         8.5                   English
# 581   December 8, 2020       89         8.6                Portuguese
# 582    October 4, 2020       83         9.0                   English
#
#     PremiereDate  Year
# 0     2019-08-05  2019
# 1     2020-08-21  2020
# 2     2019-12-26  2019
# 3     2018-01-19  2018
# 4     2020-10-30  2020
# ..           ...   ...
# 578   2018-12-31  2018
# 579   2015-10-09  2015
# 580   2018-12-16  2018
# 581   2020-12-08  2020
# 582   2020-10-04  2020
#
# [583 rows x 8 columns]

# %%
ds_date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Title         583 non-null    object
#  1   Genre         583 non-null    object
#  2   Premiere      583 non-null    object
#  3   Runtime       583 non-null    int64
#  4   IMDB Score    583 non-null    float64
#  5   Language      583 non-null    object
#  6   PremiereDate  583 non-null    datetime64[ns]
#  7   Year          583 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(5)
# memory usage: 36.6+ KB

# %%
ds['Language'].value_counts()
# Out:
# Language
# English                       400
# Hindi                          33
# Spanish                        31
# French                         20
# Italian                        14
# Portuguese                     12
# Indonesian                      9
# Japanese                        6
# Korean                          6
# German                          5
# Turkish                         5
# English/Spanish                 5
# Polish                          3
# Dutch                           3
# Marathi                         3
# English/Hindi                   2
# Thai                            2
# English/Mandarin                2
# English/Japanese                2
# Filipino                        2
# English/Russian                 1
# Bengali                         1
# English/Arabic                  1
# English/Korean                  1
# Spanish/English                 1
# Tamil                           1
# English/Akan                    1
# Khmer/English/French            1
# Swedish                         1
# Georgian                        1
# Thia/English                    1
# English/Taiwanese/Mandarin      1
# English/Swedish                 1
# Spanish/Catalan                 1
# Spanish/Basque                  1
# Norwegian                       1
# Malay                           1
# English/Ukranian/Russian        1
# Name: count, dtype: int64

# %%
ds['Genre'].value_counts()
genre = ds['Genre'].value_counts()
genre.head()
# Out:
# Genre
# Documentary        159
# Drama               77
# Comedy              49
# Romantic comedy     39
# Thriller            33
# Name: count, dtype: int64

# %%
plt.figure(figsize=(16, 5))
ds['Genre'].value_counts().head(10).plot(kind='bar', color='red')
plt.xlabel('Genre')
plt.ylabel('Number of Genre')
plt.xticks(rotation=90)
plt.show(block=True)

# %%
ds[['Genre', 'IMDB Score']].sort_values('IMDB Score', ascending=False).drop_duplicates('Genre').head(10).plot(x='Genre', y='IMDB Score', kind='bar', color='red')
plt.xlabel('Genre')
plt.ylabel('IMDB Score')
plt.show(block=True)

# %%
ds['Language'].value_counts()
# Out:
# Language
# English                       400
# Hindi                          33
# Spanish                        31
# French                         20
# Italian                        14
# Portuguese                     12
# Indonesian                      9
# Japanese                        6
# Korean                          6
# German                          5
# Turkish                         5
# English/Spanish                 5
# Polish                          3
# Dutch                           3
# Marathi                         3
# English/Hindi                   2
# Thai                            2
# English/Mandarin                2
# English/Japanese                2
# Filipino                        2
# English/Russian                 1
# Bengali                         1
# English/Arabic                  1
# English/Korean                  1
# Spanish/English                 1
# Tamil                           1
# English/Akan                    1
# Khmer/English/French            1
# Swedish                         1
# Georgian                        1
# Thia/English                    1
# English/Taiwanese/Mandarin      1
# English/Swedish                 1
# Spanish/Catalan                 1
# Spanish/Basque                  1
# Norwegian                       1
# Malay                           1
# English/Ukranian/Russian        1
# Name: count, dtype: int64

# %%
ds_lang = ds['Language'].value_counts()
ds_lang.head(5).plot(kind='bar', color='red')
plt.xlabel('Languge')
plt.ylabel('Number of Language')
plt.show(block=True)

# %%
ds.groupby('Language').agg({'Runtime': 'sum'}).sort_values('Runtime', ascending=False).head(5).plot(kind='bar',color='red')
plt.xlabel('Language')
plt.ylabel('Runtime')
plt.show(block=True)

# %%
ds_english = ds[ds['Language'] == 'English'].sort_values('IMDB Score', ascending=False)
ds_english.head()
# Out:
#                                           Title         Genre  \
# 582    David Attenborough: A Life on Our Planet   Documentary
# 580                     Springsteen on Broadway  One-man show
# 578       Taylor Swift: Reputation Stadium Tour  Concert Film
# 577  Ben Platt: Live from Radio City Music Hall  Concert Film
# 576                      Dancing with the Birds   Documentary
#
#               Premiere  Runtime  IMDB Score Language
# 582    October 4, 2020       83         9.0  English
# 580  December 16, 2018      153         8.5  English
# 578  December 31, 2018      125         8.4  English
# 577       May 20, 2020       85         8.4  English
# 576   October 23, 2019       51         8.3  English

# %%
sns.barplot(y=ds_english['Genre'].head(10), x=ds_english['IMDB Score'], color='red')
plt.show(block=True)

# %%
ds_movie = ds[['Title', 'IMDB Score']].sort_values('IMDB Score', ascending=False).head(10)
sns.barplot(y='Title', x='IMDB Score', data=ds_movie, color='red')
plt.show(block=True)

# %%
ds[['Title', 'Runtime']].sort_values('Runtime', ascending=False).head(10).plot(x='Title', y='Runtime', kind='bar', color='red')
plt.xlabel('Movie Title')
plt.ylabel('Runtime')
plt.show(block=True)

# %%
ds_date.groupby('Year').agg({'Runtime': 'sum'}).sort_values('Runtime', ascending=False).plot(kind='bar', color='red')
plt.xlabel('Year')
plt.ylabel('Sum of Runtime')
plt.show(block=True)

# %%
ds_date.groupby('Year').agg({'Title': 'count'}).sort_values('Title', ascending=False).plot(kind='bar', color='red')
plt.xlabel('Year')
plt.ylabel('Number of Film')
plt.show(block=True)
